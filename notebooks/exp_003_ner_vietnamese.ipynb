# %% [markdown]
# # Named Entity Recognition for Vietnamese
#
# This notebook does some experiments on NER task for:
#
# - English using spaCy (success ✅)
# - Vietnamese using `underthesea` (success, but problematic results 🤔)
# - Vietnamese using PhoBERT (failed to load pre-trained weights 💥)
#
# **My Conclusion**: We have nowhere to go but train our own Vietnamese NER model, at least from some pre-trained weights. See more: [Named Entity Recognition](https://github.com/undertheseanlp/NLP-Vietnamese-progress/blob/master/tasks/named_entity_recognition.md).

# %% [markdown]
# ## English (spaCy)

# %%
# Install scaCy
# See more at https://spacy.io/usage

# !conda install -c conda-forge spacy -y -q
# !python -m spacy download en_core_web_sm
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - rapidsai
#  - nvidia
#  - nodefaults
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     annotated-types-0.7.0      |     pyhd8ed1ab_0          18 KB  conda-forge
#     catalogue-2.0.10           |  py310hff52083_0          35 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     cloudpathlib-0.20.0        |     pyhd8ed1ab_0          43 KB  conda-forge
#     conda-24.11.0              |  py310hff52083_0         907 KB  conda-forge
#     confection-0.1.4           |  py310h17c5347_0          66 KB  conda-forge
#     cymem-2.0.10               |  py310hf71b8c6_0          50 KB  conda-forge
#     cython-blis-1.0.1          |  py310hf462985_0         5.6 MB  conda-forge
#     langcodes-3.4.1            |     pyhff2d567_0         151 KB  conda-forge
#     language-data-1.3.0        |     pyhff2d567_0         4.0 MB  conda-forge
#     marisa-trie-1.2.0          |  py310h76e45a6_0         178 KB  conda-forge
#     markdown-it-py-3.0.0       |     pyhd8ed1ab_0          63 KB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_0          14 KB  conda-forge
#     murmurhash-1.0.10          |  py310hf71b8c6_2          34 KB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     preshed-3.0.9              |  py310hf71b8c6_2         132 KB  conda-forge
#     pydantic-2.10.2            |     pyh3cfb1c2_0         309 KB  conda-forge
#     pydantic-core-2.27.1       |  py310h505e2c1_0         1.6 MB  conda-forge
#     rich-13.9.4                |     pyhd8ed1ab_0         181 KB  conda-forge
#     shellingham-1.5.4          |     pyhd8ed1ab_0          14 KB  conda-forge
#     smart-open-7.0.5           |       hd8ed1ab_1           7 KB  conda-forge
#     smart_open-7.0.5           |     pyhd8ed1ab_1          51 KB  conda-forge
#     spacy-3.8.2                |  py310ha2bacc8_0         5.2 MB  conda-forge
#     spacy-legacy-3.0.12        |     pyhd8ed1ab_0          28 KB  conda-forge
#     spacy-loggers-1.0.5        |     pyhd8ed1ab_0          21 KB  conda-forge
#     srsly-2.4.8                |  py310hc6cd4ac_1         557 KB  conda-forge
#     thinc-8.3.2                |  py310ha2bacc8_0         865 KB  conda-forge
#     typer-0.14.0               |     pyhd8ed1ab_0          53 KB  conda-forge
#     typer-slim-0.14.0          |     pyhd8ed1ab_0          42 KB  conda-forge
#     typer-slim-standard-0.14.0 |       hd8ed1ab_0          48 KB  conda-forge
#     wasabi-1.1.2               |  py310hff52083_1          47 KB  conda-forge
#     weasel-0.4.1               |     pyhd8ed1ab_1          41 KB  conda-forge
#     wrapt-1.17.0               |  py310ha75aee5_0          55 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        23.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   annotated-types    conda-forge/noarch::annotated-types-0.7.0-pyhd8ed1ab_0
#   catalogue          conda-forge/linux-64::catalogue-2.0.10-py310hff52083_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   cloudpathlib       conda-forge/noarch::cloudpathlib-0.20.0-pyhd8ed1ab_0
#   confection         conda-forge/linux-64::confection-0.1.4-py310h17c5347_0
#   cymem              conda-forge/linux-64::cymem-2.0.10-py310hf71b8c6_0
#   cython-blis        conda-forge/linux-64::cython-blis-1.0.1-py310hf462985_0
#   langcodes          conda-forge/noarch::langcodes-3.4.1-pyhff2d567_0
#   language-data      conda-forge/noarch::language-data-1.3.0-pyhff2d567_0
#   marisa-trie        conda-forge/linux-64::marisa-trie-1.2.0-py310h76e45a6_0
#   markdown-it-py     conda-forge/noarch::markdown-it-py-3.0.0-pyhd8ed1ab_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_0
#   murmurhash         conda-forge/linux-64::murmurhash-1.0.10-py310hf71b8c6_2
#   preshed            conda-forge/linux-64::preshed-3.0.9-py310hf71b8c6_2
#   pydantic           conda-forge/noarch::pydantic-2.10.2-pyh3cfb1c2_0
#   pydantic-core      conda-forge/linux-64::pydantic-core-2.27.1-py310h505e2c1_0
#   rich               conda-forge/noarch::rich-13.9.4-pyhd8ed1ab_0
#   shellingham        conda-forge/noarch::shellingham-1.5.4-pyhd8ed1ab_0
#   smart-open         conda-forge/noarch::smart-open-7.0.5-hd8ed1ab_1
#   smart_open         conda-forge/noarch::smart_open-7.0.5-pyhd8ed1ab_1
#   spacy              conda-forge/linux-64::spacy-3.8.2-py310ha2bacc8_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.12-pyhd8ed1ab_0
#   spacy-loggers      conda-forge/noarch::spacy-loggers-1.0.5-pyhd8ed1ab_0
#   srsly              conda-forge/linux-64::srsly-2.4.8-py310hc6cd4ac_1
#   thinc              conda-forge/linux-64::thinc-8.3.2-py310ha2bacc8_0
#   typer              conda-forge/noarch::typer-0.14.0-pyhd8ed1ab_0
#   typer-slim         conda-forge/noarch::typer-slim-0.14.0-pyhd8ed1ab_0
#   typer-slim-standa~ conda-forge/noarch::typer-slim-standard-0.14.0-hd8ed1ab_0
#   wasabi             conda-forge/linux-64::wasabi-1.1.2-py310hff52083_1
#   weasel             conda-forge/noarch::weasel-0.4.1-pyhd8ed1ab_1
#   wrapt              conda-forge/linux-64::wrapt-1.17.0-py310ha75aee5_0
#
# The following packages will be UPDATED:
#
#   conda                              24.9.0-py310hff52083_0 --> 24.11.0-py310hff52083_0
#   openssl                                  3.3.2-hb9d3cd8_0 --> 3.4.0-hb9d3cd8_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 54.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from tqdm import tqdm

# %%
nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('sentencizer')

# %%
def get_entities_from_doc(doc):
    entities = [e.text for e in doc.ents]
    return entities

def get_entity_types_from_doc(doc):
    types = [e.label_ for e in doc.ents]
    return types

def get_entities(texts, *, n_process=16, batch_size=64):
    docs = nlp.pipe(texts, n_process=n_process, batch_size=batch_size)
    entities = []
    entity_types = []
    for doc in tqdm(docs, total=len(texts)):
        entities.append(get_entities_from_doc(doc))
        entity_types.append(get_entity_types_from_doc(doc))
    return entities, entity_types

if __name__ == '__main__':
    texts = [
        'Today, I\'m travelling to the United States and I will arrive at 5 o\'clock.'
    ]
    entities, entity_types = get_entities(texts)
    for entity, entity_type in zip(entities, entity_types):
        for a, b in zip(entity, entity_type):
            print('%s [%s]' % (a, b))
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
# Today [DATE]
# the United States [GPE]
# 5 o'clock [TIME]

# %% [markdown]
# ## Vietnamese (underthesea)

# %%
# !pip install underthesea -q

# %%
from underthesea import ner

# %%
text = '''
Công ty Cổ phần Dầu Thực vật Tường An (mã CK: TAC) đã công bố BCTC quý 1/2022. 
Cụ thể, doanh thu thuần đạt 1.697 tỷ đồng tăng 7,2% so với cùng kỳ. Tuy nhiên 
giá vốn hàng bán chiếm tới 94% trong doanh thu khiến lãi gộp chỉ còn hơn 98 
tỷ đồng, giảm 55% so với quý 1/2021. Trong kỳ chi phí bán hàng giảm mạnh từ 
113,5 tỷ đồng xuống còn hơn 21 tỷ đồng, chi phí QLDN cũng thấp hơn cùng kỳ. 
Do lãi gộp thấp nên kết quả TAC vẫn báo lãi sau thuế giảm 32% so với cùng kỳ, 
đạt 53 tỷ đồng – tương đương EPS đạt 1.559 đồng.
'''
text = ' '.join(text.split())
info = ner(text)

text, info[:5]
# Out:
# ('Công ty Cổ phần Dầu Thực vật Tường An (mã CK: TAC) đã công bố BCTC quý 1/2022. Cụ thể, doanh thu thuần đạt 1.697 tỷ đồng tăng 7,2% so với cùng kỳ. Tuy nhiên giá vốn hàng bán chiếm tới 94% trong doanh thu khiến lãi gộp chỉ còn hơn 98 tỷ đồng, giảm 55% so với quý 1/2021. Trong kỳ chi phí bán hàng giảm mạnh từ 113,5 tỷ đồng xuống còn hơn 21 tỷ đồng, chi phí QLDN cũng thấp hơn cùng kỳ. Do lãi gộp thấp nên kết quả TAC vẫn báo lãi sau thuế giảm 32% so với cùng kỳ, đạt 53 tỷ đồng – tương đương EPS đạt 1.559 đồng.',
#  [('Công ty', 'N', 'B-NP', 'O'),
#   ('Cổ phần', 'V', 'B-VP', 'O'),
#   ('Dầu Thực vật', 'N', 'B-NP', 'B-LOC'),
#   ('Tường An', 'Np', 'B-NP', 'I-LOC'),
#   ('(', 'CH', 'O', 'O')])

# %%
def get_entities(texts):
    results = []
    for text in tqdm(texts, total=len(texts)):
        result = []
        items = ner(text)
        for item in items:
            entity, _, __, entity_type = item
            if entity_type == 'O':
                continue
            result.append((entity, entity_type))
        results.append(result)
    return results

entities = get_entities([text])
entities
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
# [[('Dầu Thực vật', 'B-LOC'),
#   ('Tường An', 'I-LOC'),
#   ('TAC', 'B-LOC'),
#   ('BCTC', 'B-PER'),
#   ('chi phí', 'B-LOC'),
#   ('QLDN', 'I-LOC'),
#   ('kết quả', 'B-LOC'),
#   ('TAC', 'I-LOC'),
#   ('tương đương', 'B-LOC'),
#   ('EPS', 'I-LOC')]]

# %% [markdown]
# ## Vietnamese (PhoBERT)

# %%
import torch
from transformers import AutoModelForTokenClassification, AutoTokenizer

def load_phobert_ner():
    model_id = 'vinai/phobert-large'
    model = AutoModelForTokenClassification.from_pretrained(model_id)
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    def predict(text):
        inputs = tokenizer(text, return_tensors='pt')
        with torch.no_grad():
            outputs = model(**inputs)
            labels = torch.argmax(outputs.logits, dim=-1)
        token_labels = tokenizer.convert_ids_to_tokens(labels[0].numpy())
        return token_labels
    return predict

predict_vi_ner = load_phobert_ner()
# Out:
# config.json:   0%|          | 0.00/558 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.48G [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at vinai/phobert-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.13M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
